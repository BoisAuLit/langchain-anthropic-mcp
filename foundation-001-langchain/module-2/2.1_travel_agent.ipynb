# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_mcp_adapters.client import MultiServerMCPClient

client = MultiServerMCPClient(
    {
        "travel_server": {
                "transport": "streamable_http",
                "url": "https://mcp.kiwi.com"
            }
    }
)

tools = await client.get_tools()

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver

agent = create_agent(
    "gpt-5-nano",
    tools=tools,
    checkpointer=InMemorySaver(),
    system_prompt="You are a travel agent. No follow up questions."
)

# %%
from langchain.messages import HumanMessage

config = {"configurable": {"thread_id": "2"}}

response = await agent.ainvoke(
    {
        "messages": [
            HumanMessage(
                content="Get me a direct flight from San Francisco to Tokyo on July 31st"
            )
        ]
    },
    config,
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Get me a direct flight from San Francisco to Tokyo on July 31st', additional_kwargs={}, response_metadata={}, id='4bc49ec4-cdcf-4cfc-9b3b-ad2f4e185e7a'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 834, 'prompt_tokens': 1229, 'total_tokens': 2063, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 768, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DZoafOI8iQHkFQY8P2TIHQzcMlYPW', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019dd6fb-ce07-7c23-8251-f070510579a5-0', tool_calls=[{'name': 'search-flight', 'args': {'flyFrom': 'San Francisco', 'flyTo': 'Tokyo', 'departureDate': '31/07/2026', 'passengers': {'adults': 1}, 'cabinClass': 'M', 'sort': 'price', 'curr': 'USD', 'locale': 'en'}, 'id': 'call_HiaxrFSYX9N5FO50arQdvdvF', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1229, 'output_tokens': 834, 'total_tokens': 2063, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 768}}),
#               ToolMessage(content=[{'type': 'text', 'text': '[\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2026-08-01T00:15:00.000Z",\n      "local": "2026-07-31T17:15:00.000"\n    },\n    "arrival": {\n      "utc": "2026-08-01T11:00:00.000Z",\n      "local": "2026-08-01T20:00:00.000"\n    },\n    "totalDurationInSeconds": 38700,\n    "durationInSeconds": 38700,\n    "price": 387,\n    "deepLink": "https://on.kiwi.com/2VzjJg",\n    "currency": "USD"\n  },\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2026-08-01T01:45:00.000Z",\n      "local": "2026-07-31T18:45:00.000"\n    },\n    "arrival": {\n      "utc": "2026-08-02T03:40:00.000Z",\n      "local": "2026-08-02T12:40:00.000"\n    },\n    "totalDurationInSeconds": 93300,\n    "durationInSeconds": 93300,\n    "price": 618,\n    "deepLink": "https://on.kiwi.com/nMqVXx",\n    "currency": "USD",\n    "layovers": [\n      {\n        "at": "YVR",\n        "city": "Vancouver",\n        "cityCode": "YVR",\n        "arrival": {\n          "utc": "2026-08-01T04:10:00.000Z",\n          "local": "2026-07-31T21:10:00.000"\n        },\n        "departure": {\n          "utc": "2026-08-01T17:45:00.000Z",\n          "local": "2026-08-01T10:45:00.000"\n        }\n      }\n    ]\n  },\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2026-07-31T13:03:00.000Z",\n      "local": "2026-07-31T06:03:00.000"\n    },\n    "arrival": {\n      "utc": "2026-08-01T07:00:00.000Z",\n      "local": "2026-08-01T16:00:00.000"\n    },\n    "totalDurationInSeconds": 64620,\n    "durationInSeconds": 64620,\n    "price": 647,\n    "deepLink": "https://on.kiwi.com/ISdpI3",\n    "currency": "USD",\n    "layovers": [\n      {\n        "at": "SEA",\n        "city": "Seattle",\n        "cityCode": "SEA",\n        "arrival": {\n          "utc": "2026-07-31T15:13:00.000Z",\n          "local": "2026-07-31T08:13:00.000"\n        },\n        "departure": {\n          "utc": "2026-07-31T20:30:00.000Z",\n          "local": "2026-07-31T13:30:00.000"\n        }\n      }\n    ]\n  },\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2026-07-31T13:00:00.000Z",\n      "local": "2026-07-31T06:00:00.000"\n    },\n    "arrival": {\n      "utc": "2026-08-01T05:10:00.000Z",\n      "local": "2026-08-01T14:10:00.000"\n    },\n    "totalDurationInSeconds": 58200,\n    "durationInSeconds": 58200,\n    "price": 651,\n    "deepLink": "https://on.kiwi.com/u8C4vi",\n    "currency": "USD",\n    "layovers": [\n      {\n        "at": "LAX",\n        "city": "Los Angeles",\n        "cityCode": "LAX",\n        "arrival": {\n          "utc": "2026-07-31T14:32:00.000Z",\n          "local": "2026-07-31T07:32:00.000"\n        },\n        "departure": {\n          "utc": "2026-07-31T17:55:00.000Z",\n          "local": "2026-07-31T10:55:00.000"\n        }\n      }\n    ]\n  },\n  {\n    "flyFrom": "SFO",\n    "flyTo": "HND",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2026-07-31T13:03:00.000Z",\n      "local": "2026-07-31T06:03:00.000"\n    },\n    "arrival": {\n      "utc": "2026-08-01T10:00:00.000Z",\n      "local": "2026-08-01T19:00:00.000"\n    },\n    "totalDurationInSeconds": 75420,\n    "durationInSeconds": 75420,\n    "price": 661,\n    "deepLink": "https://on.kiwi.com/AMq5P7",\n    "currency": "USD",\n    "layovers": [\n      {\n        "at": "SEA",\n        "city": "Seattle",\n        "cityCode": "SEA",\n        "arrival": {\n          "utc": "2026-07-31T15:13:00.000Z",\n          "local": "2026-07-31T08:13:00.000"\n        },\n        "departure": {\n          "utc": "2026-07-31T23:30:00.000Z",\n          "local": "2026-07-31 ...
#               AIMessage(content='Here are direct one-way options from San Francisco (SFO) to Tokyo on July 31, 2026 (economy, USD).\n\nCheapest option\n| Route | Times (local) and duration | Cabin | Return route | Return times | Return cabin | Price | Book link |\n|---|---|---|---|---|---|---|---|\n| SFO → NRT | 07/31 17:15 → 08/01 20:00 (10h 45m) | M |  |  |  | 387 USD | https://on.kiwi.com/2VzjJg |\n\nShortest duration options\n| Route | Times (local) and duration | Cabin | Return route | Return times | Return cabin | Price | Book link |\n|---|---|---|---|---|---|---|---|\n| SFO → NRT | 07/31 12:25 → 08/01 15:00 (10h 35m) | M |  |  |  | 831 USD | https://on.kiwi.com/S9YR1f |\n| SFO → NRT | 07/31 12:25 → 08/01 15:00 (10h 35m) | M |  |  |  | 858 USD | https://on.kiwi.com/AHWcAe |\n| SFO → NRT | 07/31 13:55 → 08/01 16:30 (10h 35m) | M |  |  |  | 1659 USD | https://on.kiwi.com/TRyXci |\n\nNotes\n- All options above are direct flights SFO → Tokyo (NRT). Prices shown are in USD.\n- Times are local to the departure/arrival airports.\n- If you’d like, I can book one of these for you or search for similar direct options on other dates.\n\nHave a fantastic trip! Fun fact: Tokyo is renowned for its punctual trains and a cuisine scene that ranges from street-food curiosities to multi-Michelin-starred restaurants.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 9093, 'prompt_tokens': 5578, 'total_tokens': 14671, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 8640, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DZoaqrwFcHWzyShtTK46fzIuRgN52', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019dd6fb-ffb5-7933-8bc5-200fd576b51a-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 5578, 'output_tokens': 9093, 'total_tokens': 14671, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 8640}})]}

# %%
print(response["messages"][-1].content)
# Out:
# Here are direct one-way options from San Francisco (SFO) to Tokyo on July 31, 2026 (economy, USD).
#
# Cheapest option
# | Route | Times (local) and duration | Cabin | Return route | Return times | Return cabin | Price | Book link |
# |---|---|---|---|---|---|---|---|
# | SFO → NRT | 07/31 17:15 → 08/01 20:00 (10h 45m) | M |  |  |  | 387 USD | https://on.kiwi.com/2VzjJg |
#
# Shortest duration options
# | Route | Times (local) and duration | Cabin | Return route | Return times | Return cabin | Price | Book link |
# |---|---|---|---|---|---|---|---|
# | SFO → NRT | 07/31 12:25 → 08/01 15:00 (10h 35m) | M |  |  |  | 831 USD | https://on.kiwi.com/S9YR1f |
# | SFO → NRT | 07/31 12:25 → 08/01 15:00 (10h 35m) | M |  |  |  | 858 USD | https://on.kiwi.com/AHWcAe |
# | SFO → NRT | 07/31 13:55 → 08/01 16:30 (10h 35m) | M |  |  |  | 1659 USD | https://on.kiwi.com/TRyXci |
#
# Notes
# - All options above are direct flights SFO → Tokyo (NRT). Prices shown are in USD.
# - Times are local to the departure/arrival airports.
# - If you’d like, I can book one of these for you or search for similar direct options on other dates.
#
# Have a fantastic trip! Fun fact: Tokyo is renowned for its punctual trains and a cuisine scene that ranges from street-food curiosities to multi-Michelin-starred restaurants.
