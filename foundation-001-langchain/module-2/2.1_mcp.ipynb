# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
import sys
import asyncio

# Fix for Windows issues in Jupyter notebooks
if sys.platform == "win32":
    # 1. Use ProactorEventLoop for subprocess support
    if not isinstance(
        asyncio.get_event_loop_policy(), asyncio.WindowsProactorEventLoopPolicy
    ):
        asyncio.set_event_loop_policy(asyncio.WindowsProactorEventLoopPolicy())

    # 2. Redirect stderr to avoid fileno() error when launching MCP servers
    if "ipykernel" in sys.modules:
        sys.stderr = sys.__stderr__

# %% [markdown]
# ## Local MCP server

# %%
from langchain_mcp_adapters.client import MultiServerMCPClient

client = MultiServerMCPClient(
    {
        "local_server": {
            "transport": "stdio",
            "command": "python",
            "args": ["resources/2.1_mcp_server.py"],
        }
    }
)

# %%
# get tools
tools = await client.get_tools()

# get resources
resources = await client.get_resources("local_server")

# get prompts
prompt = await client.get_prompt("local_server", "prompt")
prompt = prompt[0].content

# %%
from langchain.agents import create_agent

agent = create_agent(
    model="gpt-5-nano",
    tools=tools,
    system_prompt=prompt
)

# %%
from langchain.messages import HumanMessage

config = {"configurable": {"thread_id": "1"}}

response = await agent.ainvoke(
    {
        "messages": [
            HumanMessage(content="Tell me about the langchain-mcp-adapters library")
        ]
    },
    config=config,
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Tell me about the langchain-mcp-adapters library', additional_kwargs={}, response_metadata={}, id='95addab2-01ef-468b-971b-76df09ddb950'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 92, 'prompt_tokens': 271, 'total_tokens': 363, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 64, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DZoSzKcnueykFy3ROTOLHwCCAe6A4', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019dd6f4-8a04-7ea3-b21a-ff574b12b7c8-0', tool_calls=[{'name': 'search_web', 'args': {'query': 'langchain-mcp-adapters'}, 'id': 'call_zeczRp2UVzbSYesyXMZSLbS0', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 271, 'output_tokens': 92, 'total_tokens': 363, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 64}}),
#               ToolMessage(content=[{'type': 'text', 'text': '{\n  "query": "langchain-mcp-adapters",\n  "follow_up_questions": null,\n  "answer": null,\n  "images": [],\n  "results": [\n    {\n      "url": "https://medium.com/@deepakkamboj/the-complete-guide-to-langchain-mcp-adapters-bridging-langchain-and-model-context-protocol-3f5507cbd3ca",\n      "title": "The Complete Guide to langchain-mcp-adapters: Bridging LangChain and Model Context Protocol",\n      "content": "The `langchain-mcp-adapters` library represents a significant advancement in AI agent development, serving as a bridge between LangChain & LangGraph and Anthropic\'s Model Context Protocol (MCP). This open-source package eliminates the complexity of manual tool integration by providing seamless conversion between MCP tools and LangChain-compatible tools, enabling developers to tap into hundreds of existing MCP servers without writing custom adapters. The adapter makes it simple to connect LangChain and LangGraph with the growing ecosystem of MCP tool servers, allowing agents to pull from multiple MCP servers at once for more powerful applications. When an MCP server returns content with multiple parts like text and images, the adapter converts them to LangChain’s standard content blocks:. DEBUG=\'@langchain/mcp-adapters:tools\'. Integrated development environments, coding platforms like Replit, and code intelligence tools like Sourcegraph have adopted MCP to grant AI coding assistants real-time access to project context. By bridging LangChain\'s powerful agent framework with MCP\'s standardized tool ecosystem, it enables developers to build sophisticated, multi-tool applications without the burden of custom integrations.",\n      "score": 0.93511593,\n      "raw_content": null\n    },\n    {\n      "url": "https://changelog.langchain.com/announcements/mcp-adapters-for-langchain-and-langgraph",\n      "title": "Changelog | MCP Adapters for LangChain and LangGraph",\n      "content": "# LangChain Changelog. Sign up for our newsletter to stay up to date. # MCP Adapters for LangChain and LangGraph. The **LangChain MCP Adapters** is a package that makes it easy to use **Anthropic Model Context Protocol (MCP) tools** with LangChain & LangGraph. * Converts **MCP tools** into **LangChain- & LangGraph-compatible tools**. * Enables interaction with tools across multiple **MCP servers**. * Seamlessly integrates the **hundreds of tool servers** already published into LangGraph Agents. ### Why use MCP Adapters:. This adapter makes it simple to connect LangChain and LangGraph with the growing ecosystem of MCP tool servers. Instead of manually adapting each tool, you can now integrate them seamlessly. It also allows agents to pull from multiple MCP servers at once, making it easier to combine different tools for more powerful applications. MCP is gaining serious traction, and this adapter helps LangGraph agents take full advantage. ##### Subscribe to updates.",\n      "score": 0.93425745,\n      "raw_content": null\n    },\n    {\n      "url": "https://reference.langchain.com/python/langchain-mcp-adapters/langchain_mcp_adapters",\n      "title": "langchain_mcp_adapters | LangChain Reference",\n      "content": "##### LangChain. ##### MCP Adapters. ## LangChain Assistant. # langchain\\\\_mcp\\\\_adapters. LangChain MCP Adapters - Connect MCP servers with LangChain applications. This package provides adapters to connect MCP (Model Context Protocol) servers. with LangChain applications, converting MCP tools, prompts, and resources into. Prompts adapter for converting MCP prompts to LangChain messages. This module provides functionality to convert MCP prompt messages into LangChain. Resources adapter for converting MCP resources to LangChain Blob objects. This module provides functionality to convert MCP resources into LangChain Blob. Client for connecting to multiple MCP servers and loading LC tools/resources. to multiple MCP servers and loading tools, prompts, and resources fr ...
#               AIMessage(content='Here’s a concise overview of the langchain-mcp-adapters library and what it does.\n\nWhat it is\n- An open-source set of adapters that bridge Anthropic’s Model Context Protocol (MCP) tools with LangChain and LangGraph.\n- The goal is to let you use MCP tool servers inside LangChain/LangGraph apps without writing custom adapters for each server.\n- MCP adapters enable connecting to multiple MCP servers at once and loading their tools into LangChain-compatible form.\n\nKey features\n- Tools adapter: converts MCP tools into LangChain/LangGraph-compatible tools.\n- Prompts adapter: converts MCP prompts into LangChain messages.\n- Resources adapter: converts MCP resources into LangChain Blob objects.\n- Multi-server client: a client to connect to and load tools/prompts/resources from several MCP servers.\n- Session management: supports different MCP transport types and session configurations.\n- Interceptors and lifecycle hooks: supports lifecycle management and callback-style handling for MCP tool calls.\n- Streamable HTTP and SSE fallback (for remote MCP servers): designed to work with MCP servers that stream content.\n- Custom headers: can pass authentication or tracing headers to MCP servers with each request.\n- Automatic organization: can organize tools by server or expose a flattened collection.\n\nEcosystem and context\n- MCP stands for Model Context Protocol (Anthropic). The adapters are designed to tap into the MCP ecosystem (hundreds of tool servers) and make them usable in LangChain/LangGraph agents.\n- The library has coverage in Python (LangChain Python) and in JavaScript/TypeScript (LangChain.js) ecosystems, aligning with the LangChain tooling for both languages.\n\nWhat you can do with it\n- Connect to one or more MCP servers and load their tools into a LangChain/LangGraph workflow.\n- Build multi-tool agents that pull in tools from different MCP servers simultaneously.\n- Use MCP prompts and resources as first-class LangChain prompts and resources.\n- Integrate MCP-based tool servers into LangGraph API servers or other LangChain-powered apps.\n\nCommon usage patterns (high level)\n- Install the appropriate package for your environment (Python or JS/TS).\n- Create an MCP client that points to one or more MCP servers, optionally configuring headers for auth/tracing.\n- Load MCP tools/prompts/resources via the adapter, turning them into LangChain-compatible objects.\n- Use the resulting tools in LangChain/LangGraph agents or workflows as you would with native LangChain tools.\n\nWhere to read more (reference material)\n- Medium guide: The Complete Guide to langchain-mcp-adapters: Bridging LangChain and Model Context Protocol (overview of purpose and capabilities)\n- LangChain changelog: MCP Adapters for LangChain and LangGraph (high-level feature overview)\n- LangChain reference (Python): langchain_mcp_adapters module description (prompts, resources, tools adapters, session management, interceptor hooks)\n- GitHub repository: LangChain MCP Adapters (example usage, how to connect to MCP servers, header customization)\n- NPM package page: @langchain/mcp-adapters (JS/TS version; details on streaming, SSE fallback, multi-server support, example usage with MultiServerMCPClient)\n\nLinks (start here)\n- Medium: The Complete Guide to langchain-mcp-adapters: Bridging LangChain and Model Context Protocol\n- LangChain changelog: MCP Adapters for LangChain and LangGraph\n- LangChain Python reference: langchain_mcp_adapters\n- GitHub: langchain-ai/langchain-mcp-adapters\n- NPM: @langchain/mcp-adapters\n\nWould you like a quick-start tutorial for a specific environment?\n- Python (LangChain Python) or\n- JavaScript/TypeScript (LangChain.js)\n\nIf you prefer, I can also pull a minimal code example showing how to connect to a single MCP server and load its tools into a LangChain agent in your chosen environment.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tok ...

# %% [markdown]
# ## Online MCP

# %%
client = MultiServerMCPClient(
    {
        "time": {
            "transport": "stdio",
            "command": "uvx",
            "args": [
                "mcp-server-time",
                "--local-timezone=America/New_York"
            ]
        }
    }
)

tools = await client.get_tools()

# %%
agent = create_agent(
    model="gpt-5-nano",
    tools=tools,
)

# %%
question = HumanMessage(content="What time is it?")

response = await agent.ainvoke(
    {"messages": [question]}
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content='What time is it?', additional_kwargs={}, response_metadata={}, id='b8820979-a0a8-44c5-b5e4-1fe08b259a0e'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 347, 'prompt_tokens': 296, 'total_tokens': 643, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 320, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DZoUzAKOEwhvL2tW6CDYQzpOG61pc', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019dd6f6-7453-7ce1-b43d-b0db325400a8-0', tool_calls=[{'name': 'get_current_time', 'args': {'timezone': 'America/New_York'}, 'id': 'call_XICkjh2LxsoA4hFjroui2Ny2', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 296, 'output_tokens': 347, 'total_tokens': 643, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 320}}),
#               ToolMessage(content=[{'type': 'text', 'text': '{\n  "timezone": "America/New_York",\n  "datetime": "2026-04-28T21:59:32-04:00",\n  "day_of_week": "Tuesday",\n  "is_dst": true\n}', 'id': 'lc_c446cdba-4378-4ec6-b704-3c53842cf06c'}], name='get_current_time', id='8f658823-a0c6-4706-907b-409d4e88bde4', tool_call_id='call_XICkjh2LxsoA4hFjroui2Ny2'),
#               AIMessage(content="It's 9:59:32 PM on Tuesday, April 28, 2026 in New York (EDT, UTC−4). Want me to convert to another time zone?", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 559, 'prompt_tokens': 379, 'total_tokens': 938, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 512, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DZoV2c0KMBUiubwgVMbM36m4RpT1t', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019dd6f6-8110-7843-a6b8-487416f96038-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 379, 'output_tokens': 559, 'total_tokens': 938, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 512}})]}
