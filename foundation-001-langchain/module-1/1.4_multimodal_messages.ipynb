# %% [markdown]
# ## Text input

# %% [markdown]
# https://platform.openai.com/docs/models

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent

agent = create_agent(
    model="gpt-5-nano",
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content=[
    {"type": "text", "text": "What is the capital of The Moon?"}
])

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][-1].content)
# Out:
# In this sci‑fi setting, the capital of The Moon is Lunaria Prime.
#
# - Location: On the sunlit rim of Shackleton Crater in the Moon’s southern polar region, chosen for access to solar power and proximity to ice reserves in nearby permanently shadowed interiors.
# - Government: The Lunar Confederation’s seat of government; the Parliament towers in the central Spire and the council chambers orbit the city’s core.
# - Architecture: A fusion of regolith-arch arcologies and ice-hull modules, wrapped in a ring of solar mirrors to keep the city bright with near-constant daylight.
# - Landmarks: The Glass Spire (parliament tower), Earthrise Observatory, Aurora Gate, and the Ice Archive (a climate-controlled vault for data and ice cores).
# - Economy & life: A hub for spaceport traffic, ice harvesting, solar energy production, and research. The city hosts the annual Pulse Festival, when fluorescence-lit streets glow in a soft, polar aurora.
# - Why it’s the capital: Its gravity well is easy to access, it has abundant solar energy, and its near-polar location makes it a symbolic gateway between resource extraction in shadowed craters and scientific observation in sunlight.
#
# If you want, I can tailor Lunaria Prime to a specific era, culture, or political setup.

# %% [markdown]
# ## Image input

# %%
from ipywidgets import FileUpload
from IPython.display import display

uploader = FileUpload(accept='.png', multiple=False)
display(uploader)
# Out:
# FileUpload(value=(), accept='.png', description='Upload')

# %%
print(uploader.value)
# Out:
# ({'name': '860x394.png', 'type': 'image/png', 'size': 446532, 'content': <memory at 0x11d87b1c0>, 'last_modified': datetime.datetime(2026, 4, 23, 3, 7, 43, 677000, tzinfo=datetime.timezone.utc)},)

# %%
import base64

# Get the first (and only) uploaded file dict
uploaded_file = uploader.value[0]

# This is a memoryview
content_mv = uploaded_file["content"]

# Convert memoryview -> bytes
img_bytes = bytes(content_mv)  # or content_mv.tobytes()

# Now base64 encode
img_b64 = base64.b64encode(img_bytes).decode("utf-8")

# %%
multimodal_question = HumanMessage(
    content=[
        {"type": "text", "text": "Tell me about this capital"},
        {"type": "image", "base64": img_b64, "mime_type": "image/png"},
    ]
)

response = agent.invoke({"messages": [multimodal_question]})

print(response["messages"][-1].content)
# Out:
# What you’re looking at is Lunaris Prime, the capital of the Lunar Confederacy. A city grown out of the Moon’s crust, it sits on a bright basalt plateau ringed by shadowed craters. Earth hangs large in the sky, a constant reminder that this metropolis is both self-made and tethered to the wider human world.
#
# Here’s a closer look at Lunaris Prime:
#
# - Name and role
#   - Lunaris Prime, capital of the Lunar Confederacy (a federation of lunar settlements and orbital dependencies). It’s the political heart, financial hub, and cultural beacon of the Moon.
#
# - Location and layout
#   - Built on a sunlit terrace near a broad crater rim, with a second ring of towers shadowed by the crater’s lip. The city forms a loose, three-dimensional lattice rather than a single surface, with towers anchoring into the regolith and interconnected by sky-bridges.
#   - The skyline clusters into districts, each rising in a stepped rhythm to maximize solar exposure during the long lunar day and to hold back cold during the night.
#
# - Architecture and materials
#   - Towers are monolithic basalt with a coating of moon-glass—ceramic-like, transparent panels that harvest solar energy and store heat to moderate temperatures at night.
#   - Buildings are 3D-printed from regolith composites, then reinforced with carbon-infused latticework. Many interiors use phase-change materials to smooth out the 14.75-day day-night cycle.
#   - The effect is a city that glows softly at night, not with neon, but with bioluminescent flora preserved in public gardens and energy-efficient photonic façades that shift color with the time of day.
#
# - Governance and society
#   - The government is a rotating council system: a Civic Presidium made of representatives from districts, with a Prime Speaker who serves a two-year term.
#   - Society is pragmatic and egalitarian due to scarcity: housing, water, and air are tightly managed, but culture thrives in the margins—art, music, and sport become the city’s rebellions against monotony.
#   - People are called Lunars. Casual dress is minimal, with utility garments designed for life in a near-vacuum environment and long shifts in rotating work blocks.
#
# - Economy and technology
#   - Core industries: helium-3 mining support, water ice extraction from shaded craters, orbital-refined solar energy, and advanced 3D printing of habitat modules.
#   - Energy grid relies on in-situ generated power: solar collectors during the long day, heat storage for the long night, and a microgrid that can be reconfigured instantly for emergencies.
#   - Transportation leans on vacuum-tube pods, maglev interchanges, and tethered drone ferries for short hops between towers.
#
# - Climate and daily life
#   - The Moon has no atmosphere, so life everywhere in Lunaris Prime is inside pressurized habitats. The city uses a carefully choreographed day-night cycle to align with human circadian needs, even though the real day lasts nearly 15 Earth days.
#   - Residents work in shifts that follow the lunar schedule, with communal meals in daylight-adapted pavilions and night markets that glow with energy-efficient lightscapes.
#
# - Landmarks and districts
#   - The Lantern Gate: a monumental entrance carved into the crater rim, a ceremonial path for state decrees and public celebrations.
#   - The Glass Sea: a plaza of reflective pools that regulate temperature and serve as social spaces to gather during the long nights.
#   - The Archive Ring: a circular library network containing data cores, lunar geology records, and interplanetary archives, all accessible via holographic guides.
#   - The Lantern Spire: a towering beacon at the city’s center that broadcasts legal codes, weather forecasts, and cultural broadcasts to every district.
#   - The Moonball Arena: a gravity-adjusted stadium where citizens play a sport that blends basketball, parkour, and zero-g tradition.
#
# - Culture and life
#   - Moonfolk gatherings emphasize resilience, ingenuity, and communal effort. Music uses resonant lunar rocks and solar-augmented acoustics; theatre blends holography with live performers to tell stories of Earth-Luna relations.
#   - Public art often uses light and shadow to create dynamic installations that change with the local time and solar angle.
#
# - Current stories and tension
#   - Lunaris Prime sits at peace with Earth’s supply lines but faces tensions with remote mining enclaves that push for greater autonomy and resource rights.
#   - A recent political reform aims to open an interplanetary trade corridor for rare lunar resources while preserving the Moon’s fragile ecosystem.
#   - Rumors persist of an ancient lunar network beneath the city—an underground map of tunnels and cryptex that could reveal the Moon’s earliest settlers and forgotten technologies.
#
# A day in the life (glimpse)
# - Dawn breaks as Earth climbs into view. The Lantern Gate glows pale blue as the city powers up its morning shift grid.
# - A family emerges from a basalt-walled apartment into the communal garden, where moon-flowers bloom under luminescent panels.
# - An engineer descends the Lantern Spire’s interior shaft to monitor the heat storage tanks, passing a corridor lined with holographic histories of the Moon.
# - Night market stalls flicker on, selling nutrient-forward meals and modular tools—every item designed to be easily repaired, reconfigured, or repurposed as needs shift.
#
# If you want, I can tailor Lunaris Prime to fit a specific genre (political thriller, space opera, mystery), rename districts to fit your world, or write a short scene set in a particular district (e.g., a council debate in the Archive Ring or a footrace through the Lantern Gate). Would you like a character-driven vignette or a guided tour script of the city?

# %% [markdown]
# ## Audio input

# %%
import sounddevice as sd
from scipy.io.wavfile import write
import base64
import io
import time
from tqdm import tqdm

# Recording settings
duration = 5  # seconds
sample_rate = 44100

print("Recording...")
audio = sd.rec(int(duration * sample_rate), samplerate=sample_rate, channels=1)
# Progress bar for the duration
for _ in tqdm(range(duration * 10)):   # update 10× per second
    time.sleep(0.1)
sd.wait()
print("Done.")

# Write WAV to an in-memory buffer
buf = io.BytesIO()
write(buf, sample_rate, audio)
wav_bytes = buf.getvalue()

aud_b64 = base64.b64encode(wav_bytes).decode("utf-8")
# Out:
# Recording...
# 100%|██████████| 50/50 [00:05<00:00,  9.45it/s]
# Done.

# %%
agent = create_agent(
    model='gpt-4o-audio-preview',
)

multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this audio file"},
    {"type": "audio", "base64": aud_b64, "mime_type": "audio/wav"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
