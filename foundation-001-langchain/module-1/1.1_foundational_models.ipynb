# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Initialising and invoking a model

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(model="gpt-5-nano")

# %%
response = model.invoke("What's the capital of the Moon?")

response
# Out:
# AIMessage(content='There isn’t one. The Moon has no government or country, so it has no capital. (In fiction people sometimes invent capitals like “Lunapolis” or “Selene City,” but there’s no real one.)', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 630, 'prompt_tokens': 13, 'total_tokens': 643, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 576, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DXckZGBNsqfFU1ebiTjEJp61Z3SzS', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019db7dc-208d-78f2-8a83-85220c6ed94a-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 630, 'total_tokens': 643, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 576}})

# %%
print(response.content)
# Out:
# There isn’t one. The Moon has no government or country, so it has no capital. (In fiction people sometimes invent capitals like “Lunapolis” or “Selene City,” but there’s no real one.)

# %%
from pprint import pprint

pprint(response.response_metadata)
# Out:
# {'finish_reason': 'stop',
#  'id': 'chatcmpl-DXckZGBNsqfFU1ebiTjEJp61Z3SzS',
#  'logprobs': None,
#  'model_name': 'gpt-5-nano-2025-08-07',
#  'model_provider': 'openai',
#  'service_tier': 'default',
#  'system_fingerprint': None,
#  'token_usage': {'completion_tokens': 630,
#                  'completion_tokens_details': {'accepted_prediction_tokens': 0,
#                                                'audio_tokens': 0,
#                                                'reasoning_tokens': 576,
#                                                'rejected_prediction_tokens': 0},
#                  'prompt_tokens': 13,
#                  'prompt_tokens_details': {'audio_tokens': 0,
#                                            'cached_tokens': 0},
#                  'total_tokens': 643}}

# %% [markdown]
# ## Customising your Model

# %%
model = init_chat_model(
    model="gpt-5-nano",
    # Kwargs passed to the model:
    temperature=1.0,
)

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# There isn’t one. The Moon isn’t a country or city, so it has no capital.
#
# If you meant something else:
# - If you’re joking about capitalization, the capital letter of the word “Moon” is M.
# - Some science fiction stories imagine a lunar city or capital, but none exists in reality.

# %% [markdown]
# ## Model Providers

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %%
model = init_chat_model(model="claude-sonnet-4-5")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# The Moon doesn't have a capital because it's not a country or inhabited territory. It's Earth's natural satellite - a celestial body with no permanent population or government.
#
# If you're asking about proposed lunar bases or settlements, none exist yet, though several countries and private companies have plans for future lunar outposts.

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# That's a fun question! The Moon doesn't have a capital city in the way that Earth countries do. It's a natural celestial body, not a political entity.
#
# However, if we were to imagine a "capital" in a playful sense, we might consider places that are:
#
# *   **Historically significant for human exploration:** Like **Tranquility Base**, where Neil Armstrong and Buzz Aldrin first landed.
# *   **Geologically interesting or prominent:** Perhaps a large crater like **Tycho** or a prominent mountain.
# *   **Areas of potential future settlement:** If humans were to establish bases, those might become centers of activity.
#
# But officially, there's no capital of the Moon. It remains a wild and wonderful place!

# %% [markdown]
# ## Initialising and invoking an agent

# %%
from langchain.agents import create_agent

agent = create_agent(model=model)

# %%
agent = create_agent(model="claude-sonnet-4-5")

# %%
agent = create_agent("gpt-5-nano")

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='002a606e-ab20-46c1-8e30-697bb51ecc29'),
#               AIMessage(content='There isn’t one. The Moon isn’t a country and has no government, so it has no capital. If humans someday establish a lunar settlement with a government, they’d decide a capital then.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 369, 'prompt_tokens': 13, 'total_tokens': 382, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 320, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DXcph7NjpRXyLt1TQuJKk8atmkvYL', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019db7e0-fc67-7031-beb7-dd03e983ba5f-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 369, 'total_tokens': 382, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 320}})]}

# %%
print(response['messages'][-1].content)
# Out:
# There isn’t one. The Moon isn’t a country and has no government, so it has no capital. If humans someday establish a lunar settlement with a government, they’d decide a capital then.

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City")]}
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='c17d381c-a319-4d32-afe7-b705b61de266'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='acbab7b7-a1c1-42e2-9699-3049dabc2cbd', tool_calls=[], invalid_tool_calls=[]),
#               HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='3067b93f-12c4-44b4-9b81-22ac7fc35421'),
#               AIMessage(content='There isn’t an official capital of the Moon. Luna City is a fictional idea you can use for worldbuilding or storytelling. Here’s a ready-to-use, richly imagined version you can adapt:\n\n- Concept and setting\n  - Luna City is a sprawling lunar metropolis built inside and around a large equatorial crater, protected by a transparent shield and linked by a network of rings, tubes, and elevators. Living areas sit in rotating, gravity-modulated habitats to simulate Earth-like gravity, while some zones let residents experience near Moon gravity or microgravity for work and research.\n  - Population: roughly a few million residents across multiple habitats, with a mix of scientists, engineers, technicians, families, and support staff.\n\n- Governance and society\n  - Ruled by the Lunar Cooperative Council (LCC), a multi-district body elected by residents. Each district has delegation seats, and major decisions require broad consensus and independent audits.\n  - Key values: open data, resource sharing, long-term sustainability, and strong Earth-Luna collaboration. Education and healthcare are universal, with a strong emphasis on lifelong learning and scientific literacy.\n\n- Economy and technology\n  - Core industries: in-situ resource utilization (water ice processing and hydrogen/oxygen production), 3D printing and manufacturing from lunar regolith, life-support systems, and high-end research (astronomy, materials science, biology living in closed-loop ecosystems).\n  - Energy: mix of solar farms on the crater rim and shielded, modular nuclear microplants for peak demand. Power and data are tightly integrated via smart grids.\n  - Transportation: maglev or light-rail pods along a ring network, vertical transit towers, and some gravity-assisted workspaces. Everyday life often uses shorter trips in the local districts.\n\n- Districts and landmarks\n  - Core Dome: administrative hub with the council chambers, archives, and central command for life support.\n  - Residential Arc: stacked habitats with 1g-equivalent living spaces, schools, clinics, and parks.\n  - Greenbelt Dome: agriculture and biomes, hydroponic farms, and community gardens that provide fresh food and air quality benefits.\n  - Research Spire: laboratories for physics, astronomy, biology, and materials science; large telescopes peek past the shield into space.\n  - Market Gorge: trade, cultural venues, eateries featuring lunar-grown produce, art studios, and a lunar-night festival street.\n  - Observatory Gate: public observatory and education center with a view of Earth and deep-space objects.\n  - Ice Gate (pole-adjacent): access to water-ice resources and a logistics hub for inbound/outbound supplies.\n\n- Daily life, culture, and challenges\n  - Everyday life balances high-tech efficiency with community spaces: schools via holographic tutors, public parks with low-gravity play areas, and cultural festivals that blend Earth traditions with lunar-inspired art.\n  - Culture: multilingual (common trade languages plus local dialects), music concerts in domed arenas, and art that reflects living between Earth and Moon.\n  - Challenges: radiation shielding, psychological well-being from isolation, supply chain resilience, dust management, and maintaining healthy bone and muscle mass in partial gravity. All residents train in space medicine and emergency response.\n\n- A short vignette (to spark ideas)\n  - Dawn breaks over the Ice Gate, and a transport pod slips along a metal spine of rails, hugging the crater’s edge. Inside Core Dome, Dr. Mina Rao checks the life-support readouts while her apprentice stars at the Earth through a glass pane. The city hums with solar collectors unfurling like wings, greenhouses singing with the scent of fresh greens, and the soft thrum of gravity plates keeping feet firmly planted as they plan the day’s experiments.\n\nIf you’d like, I can tailor this to a specific vibe (grim cyberpunk, hopeful utopia, ki ...

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {
        "messages": [
            HumanMessage(content="Tell me all about Luna City, the capital of the Moon")
        ]
    },
    stream_mode="messages",
):
    # token is a message chunk with token content
    # metadata contains which node produced the token

    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
# Out:
# There isn’t a real Luna City today—the Moon doesn’t have a capital city in our world. If you’re asking for a fictional concept you can use in a story, game, or world-building project, here’s a richly developed idea you can run with or adapt to your needs.
#
# Overview
# - Name: Luna City, the Capital of the Moon (in-universe title: Luna City Prime, sometimes just “Luna Prime”).
# - Purpose: The political, economic, and cultural heart of a Moon-wide federation or alliance. It houses the Lunar Council, major research institutions, the central market, and the main spaceport complex.
# - Tone: A blend of hard sci-fi practicality and awe-inspiring architecture. Think utilitarian efficiency meets elegant, gravity-reduced design.
#
# Location and geography
# - Location: A plateau near the southern polar region, adjacent to permanently shadowed craters that guard ice resources. The site leverages near-continuous sunlight on the rim and a network of solar shade structures to feed power into the city day and night.
# - Why this location: Water ice is a strategic asset for life support and fuel. The city’s position makes ice processing, solar power generation, and deep-ice logistics central to its economy. The crater rims and nearby lava-tube networks provide natural shielding and ideal real estate for subterranean districts.
# - Environment: Vacuum with no breathable atmosphere; extreme temperature swings; high-radiation exposure unless shielded. The city relies on regolith shielding, pressurized habitats, and a closed-loop life-support system.
#
# Government and politics
# - Political structure: A lunar federation or alliance with a central governing body, the Lunar Council. Luna City Prime functions as the administrative capital and seat of the Council.
# - Local governance: The Governor of Luna City administers day-to-day affairs. A bicameral or tricameral system (for flavor) might exist: a Council of Craters (resource and infrastructure), a People’s Assembly (citizen interests, districts), and an Expert Board (science, engineering, and policy). Elections are held on a lunar cycle derived from the 29.5-day synodic month, with Earth-time synchronization for interplanetary relations.
# - Law and order: A space-law framework governs resource rights, water ice extraction, and planetary protection. The city maintains a Tourism and Transit Authority, a Cybernetics and AI Ethics Board, and a Public Works Directorate.
#
# Economy and resources
# - Core industries:
#   - Ice processing and water supply networks (essentials for life support, agriculture, and fuel).
#   - Solar power generation and energy storage (massive solar farms and reflective light-well tunnels feeding power to underground districts).
#   - Advanced manufacturing and 3D printing (building habitats, tools, and components from lunar regolith).
#   - Helium-3 and isotope mining (research and propulsion uses).
#   - Biotech and closed-loop agriculture (greenhouses in shielded domes or lava-tube farms).
# - Trade: Earth governments, orbital habitats, and Martian outposts trade essential goods, rare metals, and research data. Luna City Prime earns revenue from infrastructure leases, energy credits, and licensing for mining subsurface rights.
# - Daily life economy: Local markets trade in water, nutrient-rich algae sheets, lunar glass products, art carved from regolith, and high-efficiency life-support systems.
#
# City layout and districts
# - Central hub (The Core): The political heart with the Lunar Council chambers, key ministries, and the grand ceremonial plaza. Elevated, shielded, and highly engineered for security and data visibility.
# - Administrative row (The Arcology Ring): Layered residential-toward-work complexes connected by gravity-defying transit tubes. Mixed-use districts with schools, clinics, and small businesses.
# - Market and exchange district (The Ice Market): Ice-processing facilities feed into a bustling bazaar of goods, crafts, and tech services. A ledger of trade is openly displayed in holographic boards.
# - Research and archives (The Lab and The Vault): World-class labs, data centers, and the Archive—an enormous facility preserving history, experiments, and planetary data.
# - Green and blue districts (The Helix Greenways): Underground and semi-surface farms using hydroponics and regolith insulation; living quarters with gravity-modified design to reduce bone and muscle loss.
# - Port and logistics (The Gate): Landing pads, freighter docks, and vehicle depots. A protective ring of shielding domes around the port hums with maintenance robots.
# - Culture and public life (The Lantern Quarter): Public plazas, art installations, theaters, and small museums—designed to be legible in 1/6 g, with gravity-friendly art and kinetic sculptures.
# - Data and education (The Archive Campus): Universities, think-tanks, and citizen science labs; open access to data streams from orbital satellites and lunar experiments.
# - Underground network (Undergrid): A labyrinth of lava-tube transit tunnels and utility conduits connecting districts, shielding critical functions from temperature swings and radiation.
#
# Architecture, tech, and daily life
# - Architecture: A fusion of art-deco geometry and practical lunar 3D-printed latticework. Buildings use basalt/regolith composites, translucent glass-like materials for daylighting, and internal gravity adjustments to aid movement.
# - Shielding and habitat design: Shielded residential modules with layered regolith walls, radiation-hardened electronics, and airlocks between surface and subsurface zones.
# - Transportation: Gravity-adapted transit—magnetic rails, tube transport, and short-range hover pods. Surface movement often happens through pressurized corridors or underground routes to minimize exposure to radiation and micrometeoroids.
# - Energy: A network of solar collectors, precision-dish reflectors, energy storage in advanced batteries, and compact reactors or safe nuclear options for nights or eclipse periods.
# - Food and water: Hydroponic farms, algae bioreactors, and fully closed-loop hydroponics with water recycling and air revitalization. Local food is diverse: leafy greens, algae proteins, mushroom-like crops, and lab-grown meat substitutes.
# - Culture: A multilingual society using Earth languages plus a lunar civic lingua (Lunite) that blends terms from major Earth cultures. Timekeeping can run on lunar time for local life with Earth-time coordination for interplanetary work.
#
# Society and culture
# - Population: A mix of Earth-descended workers, Moon-born residents raised in lunar life, scientists, engineers, and an emergent generation of AI-assisted governance counselors.
# - Daily life: Residents live in modular units with shared spaces for meals, education, and recreation. Workdays balance shift rotations to maximize sunlight for energy and safety in a hostile environment.
# - Education and research: The city prioritizes STEM education, planetary science, AI ethics, and habitat design. Open data policies encourage citizen science and collaboration with Earth universities.
# - Entertainment and cuisine: Public performances in gravity-friendly spaces, lunar cinema in low or 1/6g, and culinary innovations that emphasize algae, hydroponic produce, and preserved Earth-imports.
#
# Notable institutions and people (examples you can populate)
# - Lunar Council Hall: The ceremonial seat of power.
# - Institute of Regolith Engineering: Research into shielding, mining, and building with lunar soil.
# - The Archive of Light: A massive data repository preserving lunar history, experiments, and policy records.
# - The Ice Market Consortium: Oversees water ice extraction, processing, and sale.
# - Notable archetypes you might feature:
#   - A Governor or Council Chair who pushes for increased autonomy from Earth-based authorities.
#   - A lead engineer who rewrites life-support algorithms to handle a solar flare.
#   - A researcher who discovers unexpected water ice pockets or a new, valuable mineral.
#   - A civic activist leading a movement for openness and citizen oversight.
#
# History timeline (quick sketch)
# - 2030s–2050s: Early human outposts and ice-mining operations establish a foothold near the lunar poles.
# - 2060s: The first self-sustaining habitats are built underground to protect residents from radiation; a governance framework emerges to manage resources.
# - 2070s: Luna City Prime is founded as the political and economic capital; major research institutions relocate there.
# - 2080s–2090s: Rapid expansion of districts, transit tubes, and energy infrastructure; the city becomes a symbol of lunar autonomy and scientific achievement.
# - 2100s: The Lunar Council codifies interplanetary trade standards; Luna City becomes a hub for science, culture, and space governance.
#
# Story seeds and plot hooks
# - A water-ice heist: A shell game involving diverted ice shipments or a submerged cavern beneath a lava tube reveals a larger conspiracy about water control.
# - AI governance test: An artificial intelligence counselor begins proposing radical reforms—are its suggestions ethical or dangerous?
# - Solar flare fallout: A powerful solar flare disrupts power and life-support; engineers race to repair the grid before life-support limits are breached.
# - Underground archaeology: Mapping a long-forgotten lava-tube network uncovers ancient lunar artifacts that alter current energy or water rights.
# - Autonomy movement: A faction in Luna City Prime pushes for full independence from Earth-negotiated treaties, sparking political drama and diplomacy.
#
# Tone and styles you can pick
# - Hard sci-fi realism: Emphasize plausible physics, engineering challenges, and logistics.
# - Utopic lunar life: Focus on sustainable design, social equity, and harmonious living with the harsh lunar environment.
# - Gritty cyberpunk: Shadows beneath the shielded surfaces, political intrigue, black-market tech, and AI-driven power plays.
# - Adventure space opera: Clear heroes and villains, high-stakes missions, and sweeping, cinematic visuals of a city on the edge of the Moon.
#
# If you’d like, I can tailor Luna City to your preferred genre, audience, and plot ideas. For example:
# - A 1-page city bible with a map-style description of districts and key landmarks.
# - A short sample scene in Luna City Prime—a day in the life of a resident, a council dispute, or a tense arrival at The Gate.
# - A quick “how to run” guide for a game set in Luna City Prime, including encounter ideas, factions, and quest hooks.
#
# Would you like me to adjust this concept to a specific tone (hard sci-fi, utopian, cyberpunk, etc.), or provide a map layout and detailed floor plans for the central districts?
