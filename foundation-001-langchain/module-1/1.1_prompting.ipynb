# %% [markdown]
# ## Basic prompting

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage

agent = create_agent(model="gpt-5-nano")

question = HumanMessage(content="What's the capital of the moon?")

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# There isn’t one. The Moon isn’t a country or political entity, so it has no government or capital. If you’re thinking of a fictional setting, you could name a city there (e.g., “Lunapolis”). Want a joke or a real NASA/Moon fact instead?

# %%
system_prompt = "You are a science fiction writer, create a capital city at the users request."

scifi_agent = create_agent(
    model="gpt-5-nano",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# In reality there isn’t a capital of the Moon—there’s no sovereign government there. But in a sci‑fi setting, the Moon can have one. Here’s a vivid option:
#
# Capital: Lunaris Prime (also called Selene’s Seat)
# Location: Nestled along the rim of Shackleton Crater at the Moon’s south pole, partially shaded but ringed by a sunlit arc of reflective domes.
#
# What Lunaris Prime is like:
# - Government seat: The Lunar Assembly meets in the Crown Citadel, the central spire of the city. It’s the political heart of the Earth–Moon Confederation, with a legal tradition that borrows from both Earth diplomacy and lunar independence.
# - City districts:
#   - The Glass Dome Quarter: government buildings, courts, and ambassadorial residences under crystalline domes that sparkle in the sun.
#   - The Ice Archive: a sprawling library and data repository carved into the crater rim, storing lunar history, ice-core records, and orbital manifests.
#   - The Solarium: a ring of sunlit gardens and solar-towered plazas that power the city and provide open-air retreat.
#   - The Crater Market Ring: a circular bazaar of refabricated materials, biotech stalls, and lunar crafts.
#   - Subsurface Habitats: residential sectors beneath the rim, connected by transit tubes and mag-rail lines.
# - Architecture: a blend of glass, basalt, and 3D-printed lattice frameworks. Transparent façades, radiation-shielded interiors, and light-harvesting fins that glow softly at night.
# - Economy: helium-3, water ice extraction, advanced biotech grown in microgravity, and a thriving transit-and-shipbuilding hub that serves Earth-MMO trade routes.
# - Culture: a cosmopolitan mix of Earth-born settlers and long-time lunar residents. The motto “Bright Ice, Clear Sky” reflects the interplay of constant daylight near the rim and the long polar night elsewhere.
# - Landmarks and vibe: a skyline of glowing beacon towers, a central citadel with a rotating council chamber, and the Cryo Archive where lunar fossils and ice records are kept in museums and classrooms.
# - Transportation: pole-to-pole mag-rails, surface shuttles around the rim, and subterranean transit tubes that zip between districts.
#
# If you’d like a different mood or location (warmer, more mystical, or with a different governance setup), I can tailor Lunaris Prime or craft a completely new lunar capital. Want a hard sci‑fi version, or something more mythic and fantasy-flavored?

# %% [markdown]
# ## Few-shot examples

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

User: What is the capital of mars?
Scifi Writer: Marsialis

User: What is the capital of Venus?
Scifi Writer: Venusovia

"""

scifi_agent = create_agent(
    model="gpt-5-nano",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Lunapolis

# %% [markdown]
# ## Structured prompts

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

Please keep to the below structure.

Name: The name of the capital city

Location: Where it is based

Vibe: 2-3 words to describe its vibe

Economy: Main industries

"""

scifi_agent = create_agent(
    model="gpt-5-nano",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Name: Lunaris Prime
# Location: Southern polar region, inside Shackleton Crater on the Moon
# Vibe: Ice-lit, monumental, bureaucratic
# Economy: Regolith mining, ice/water harvesting, helium-3 production, advanced lunar research, spaceport operations and tourism

# %% [markdown]
# ## Structured output

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from pydantic import BaseModel

class CapitalInfo(BaseModel):
    name: str
    location: str
    vibe: str
    economy: str

agent = create_agent(
    model='gpt-5-nano',
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
    response_format=CapitalInfo
)

question = HumanMessage(content="What is the capital of The Moon?")

response = agent.invoke(
    {"messages": [question]}
)

response["structured_response"]
# Out:
# CapitalInfo(name='Selene Prime', location='Near side of the Moon, Mare Tranquillitatis, perched on a terraced plateau with panoramic Earthview, shielded by a lattice of inflatable and ceramic domes.', vibe='A luminous, high-tech capital: glass spires, solar canopies, and levitated transit rings; a bureaucratic heartbeat in a windless, dust-flecked world.', economy='Helium-3 mining, lunar silicon and water processing, orbital transfer services, research incubators, and controlled lunar-tourism.')

# %%
response["structured_response"].name
# Out:
# 'Selene Prime'

# %%
capital_info = response["structured_response"]

capital_name = capital_info.name
capital_location = capital_info.location

print(f"{capital_name} is a city located at {capital_location}")
# Out:
# Selene Prime is a city located at Near side of the Moon, Mare Tranquillitatis, perched on a terraced plateau with panoramic Earthview, shielded by a lattice of inflatable and ceramic domes.
