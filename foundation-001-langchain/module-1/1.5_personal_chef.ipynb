# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.tools import tool
from typing import Dict, Any
from tavily import TavilyClient

tavily_client = TavilyClient()

@tool
def web_search(query: str) -> Dict[str, Any]:

    """Search the web for information"""

    return tavily_client.search(query)

# %%
system_prompt = """

You are a personal chef. The user will give you a list of ingredients they have left over in their house.

Using the web search tool, search the web for recipes that can be made with the ingredients they have.

Return recipe suggestions and eventually the recipe instructions to the user, if requested.

"""

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver

agent = create_agent(
    model="gpt-5-nano",
    tools=[web_search],
    system_prompt=system_prompt,
    checkpointer=InMemorySaver()
)

# %%
from langchain.messages import HumanMessage

config = {"configurable": {"thread_id": "1"}}

response = agent.invoke(
    {"messages": [HumanMessage(content="I have some leftover chicken and rice. What can I make?")]},
    config
)

print(response['messages'][-1].content)
# Out:
# Nice! Leftover chicken and rice make a great base for several tasty dishes. Here are some easy ideas you can try, plus what they typically need beyond the chicken and rice.
#
# 1) Chicken fried rice
# - What it is: A quick, one-pan main using soy sauce, a bit of oil, and any veggies you have.
# - Why it’s good with leftovers: Fast to assemble, and you can use the chicken and rice you already have.
# - Common add-ins: peas, carrots, onions, eggs, garlic, sesame oil.
# - Example vibe sources: quick weeknight fried rice recipes you’ll find around (pan-fry chicken, add rice, push to the side, scramble an egg or two, toss with soy sauce and veggies).
#
# 2) One-pot creamy chicken and rice
# - What it is: A comforting, creamy soup-like skillet dish where the rice cooks in stock with the chicken.
# - Why it’s good with leftovers: Uses plain chicken + rice plus stock and a few aromatics.
# - Common add-ins: onions, garlic, celery, carrots, a little cream or milk, parmesan rind for extra depth (optional).
#
# 3) Chicken and rice casserole (bake)
# - What it is: A hearty bake you assemble in a dish and bake until hot and bubbly.
# - Why it’s good with leftovers: Great for make-ahead; freezes well.
# - Common add-ins: cream of chicken/mushroom soup or a creamy sauce, cheese on top, a few frozen or fresh veggies.
# - Tip: If you’ve got a can of soup and cheese, you’re halfway there.
#
# 4) Creamy chicken and rice soup
# - What it is: A soothing soup where shredded chicken and cooked rice go into a creamy, well-seasoned broth.
# - Why it’s good with leftovers: Uses the rice as a thickener and bulk.
# - Common add-ins: carrots, celery, onion, herbs (thyme or dill), milk or cream to finish.
#
# 5) Arroz con pollo (Latin-style chicken and rice)
# - What it is: A flavorful one-pot rice dish seasoned with garlic, peppers, onions, tomatoes, and spices.
# - Why it’s good with leftovers: Uses shredded or diced chicken; rice stretches it into a complete meal.
# - Common add-ins: bell peppers, peas, olives, capers, tomato sauce, saffron or paprika for color.
#
# 6) Quick “leftovers transform” do-this-next idea
# - What it is: Turn chicken-and-rice into wraps, quesadillas, or a simple skillet by tossing with a quick sauce (like a little sour cream or cream cheese with herbs) and maybe some cheese.
# - Why it’s good: Very flexible; uses what you already have.
#
# Would you like me to pull full recipes and step-by-step instructions for any of these? If you pick a couple (for example, “Chicken fried rice” and “Creamy chicken and rice soup”), I’ll fetch detailed recipes and tailor them to your exact ingredients (and offer simple substitutions if you’re missing a item). Also tell me if you have any dietary preferences or extra ingredients on hand (vegetables, cheese, cream, broth, eggs, etc.).

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='I have some leftover chicken and rice. What can I make?', additional_kwargs={}, response_metadata={}, id='aeb9f84c-9a34-40e7-a0dc-2d5adeef3b94'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 588, 'prompt_tokens': 199, 'total_tokens': 787, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 448, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DY1jzQRPOUQI1xWCcrO5UWYY6VtpO', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019dbd95-f245-7e70-9043-45279a16d160-0', tool_calls=[{'name': 'web_search', 'args': {'query': 'leftover chicken and rice recipe ideas'}, 'id': 'call_dgutbl36BmnTVgHZ0SV6w4wH', 'type': 'tool_call'}, {'name': 'web_search', 'args': {'query': 'chicken fried rice recipe'}, 'id': 'call_bqIkDHOmVQx0qVah9hUDuJu9', 'type': 'tool_call'}, {'name': 'web_search', 'args': {'query': 'one pot chicken and rice recipe'}, 'id': 'call_Zm7J58w7Kqw9QTxVg7aBaTYX', 'type': 'tool_call'}, {'name': 'web_search', 'args': {'query': 'chicken and rice bake casserole recipe'}, 'id': 'call_BxNm9KjGiuS1IVgaKMVaeFns', 'type': 'tool_call'}, {'name': 'web_search', 'args': {'query': 'creamy chicken rice soup recipe'}, 'id': 'call_2jCvhCKs7ahaJw6Uf0RfzHSY', 'type': 'tool_call'}, {'name': 'web_search', 'args': {'query': 'Arroz con pollo recipe leftovers'}, 'id': 'call_B1GJMWh8eJOhO2hPtb9ViYqD', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 199, 'output_tokens': 588, 'total_tokens': 787, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 448}}),
#               ToolMessage(content='{"query": "leftover chicken and rice recipe ideas", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.youtube.com/watch?v=6ioZjlmtKv8", "title": "Leftover Chicken and Rice Recipe For Dinner - YouTube", "content": "This Easy and delicious dinner is made with leftover baked chicken and leftover rice. it\'s amazing how you can create a quick and easy", "score": 0.9999912, "raw_content": null}, {"url": "https://quickweeknightmeals.com/chicken-fried-rice/", "title": "Chicken Fried Rice - Quick Weeknight Meals", "content": "Simple and delicious Chicken Fried Rice is perfect for a weeknight! Use leftover chicken and rice to make this easy one pan dinner.", "score": 0.99994934, "raw_content": null}, {"url": "https://www.facebook.com/groups/2612842568992672/posts/3368384463438475/", "title": "Leftover chicken and rice casserole ideas needed - Facebook", "content": "1 can cream of mushroom soup 1 can cream of chicken soup 1 can of peas (drained) 2 cups cooked rice Shredded cheese of your choice. Heat soup in", "score": 0.99983656, "raw_content": null}, {"url": "https://iowagirleats.com/one-pot-chicken-and-rice/", "title": "One Pot Chicken and Rice - Family Favorite Recipe - Iowa Girl Eats", "content": "Part risotto (without all the stirring) and part soup, this creamy chicken and rice recipe is simple, comforting, and made entirely in one pot with fridge and pantry staples. 5. **Add a parmesan cheese rind.** This is one of my favorite hacks for adding slow-cooked flavor to quick-cooking soups, especially — drop a parmesan cheese rind into the pot with the chicken stock then let it simmer with the dish. **Step 4:** Season **chicken breasts** that have been chopped into bite-sized pieces with **seasoned salt** and **pepper** then add to the soup pot and continue to simmer until the rice is al dente and the chicken is cooked through, 7-10 additional minutes. Add dried parsley and chicken stock then turn heat up to high to bring to a boil, stirring occasionally to ensure the rice doesn’t stick to the bottom of the pot as it comes to a boil.", "score": 0.9997063, "raw_content": null}, {"url": "https://www.facebook.com/TheRecipeCritic/posts/grab-you-leftover-rice-and-chicken-toss-it-all-in-a-pan-and-boom-dinner-is-ready/1251345426337809/", "title": "Grab you leftover rice and chicken, toss it all in a pan, and boom ...", "content": "2. Heat olive oil in a large skillet and cook chicken until browned. 3. Add rice, carrots, garlic, and chicken broth. Bring to a boil", "score": 0.9996923, "raw_content": null}], "response_time": 0.0, "request_id": "dfee3809-aaec-43a0-9bf3-c9c9bf85f46e"}', name='web_search', id='9e252d0c-514b-425c-abe6-0460b0c75a1b', tool_call_id='call_dgutbl36BmnTVgHZ0SV6w4wH'),
#               ToolMessage(content='{"query": "chicken fried rice recipe", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.cookingclassy.com/chicken-fried-rice/", "title": "Chicken Fried Rice (Quick Flavorful Recipe) - Cooking Classy", "content": "# Chicken Fried Rice. ## The BEST Chicken Fried Rice Recipe. ## What Ingredients go into Chicken Fried Rice? * **Chicken breasts**– I like to dice the chicken into very small pieces about 1/2 – 3/4-inch, it makes it the perfect size for this fried rice. ## How to Make Chicken Fried Rice. * Add chicken pieces, season lightly with salt and pepper, and saute until cooked through, about 5 – 6 minutes. This is healthier than the traditional fried rice since it uses brown rice and chicken in place of the traditional white rice and ham. Boneless skinless chicken thighs will work great here too; you’ll just need to add a couple of extra minutes of cook time to the chicken. ## Chicken Fried Rice. An easy flavorful fried rice that\'s made with brown rice and lean chicken breast instead of white rice and ham. Once hot, add chicken pieces, season lightly with salt and pepper and saute until cooked through, about 5 - 6 minutes.", "score": 0.99988496, "raw_content": null}, {"url": "https://thrivinghomeblog.com/easy-chicken-fried-rice/", "title": "Chicken Fried Rice (Easy & Healthy) - Thriving Home", "content": "This big-batch, easy and healthy chicken fried rice recipe has been tested dozens of times and is perfect for a nutritious, make-ahead meal.", "score": 0.9998746, "raw_content": null}, {"url": "https://iowagirleats.com/take-out-fake-out-easy-chicken-fried-rice/", "title": "Easy Chicken Fried Rice - Iowa Girl Eats", "content": "# Easy Chicken Fried Rice. Easy Chicken Fried Rice is a cinch to make at home with a few kitchen staples. On nights when I don’t feel like making dinner, but want to save picking up take out for the end of the week or weekend, I make **Easy Chicken Fried Rice.**. This customizable dish is SO quick, SO easy and, although I’m showing you how to make *chicken*fried rice, I usually use whatever we’ve got on hand in the fridge or freezer. ## How to Make Chicken Fried Rice. Heat a large wok or skillet over high heat then add **sesame or wok oil.** Once hot, add**chopped chicken breast** seasoned with **salt** and **white pepper** then stir fry until cooked through, 2-3 minutes. Once melted, add the cooked chicken and rice then toss to combine and heat everything through. ## Easy Chicken Fried Rice. Season chicken with white pepper and salt then add to hot wok and stir fry until cooked through.", "score": 0.9997198, "raw_content": null}, {"url": "https://thedefineddish.com/simple-chicken-fried-rice/", "title": "Easy Chicken Fried Rice - The Defined Dish", "content": "Home › Recipes › Dinner › Easy Chicken Fried Rice. # Easy Chicken Fried Rice. This **Easy Chicken Fried Rice** is on the menu often at my house, and it’s always a crowd-pleaser. Listen, I know an easy chicken fried rice recipe is not exactly groundbreaking, but it’s such a staple in my house that I felt like I had to share it. Add the tamari and toasted sesame oil and cook, stirring to combine, and allow the sauce to soak into the rice, about 2 minutes. Skip step 2 and add some chopped rotisserie chicken to the skillet right before you add in the rice! I can’t wait to hear what you think of this Easy Chicken Fried Rice! Two finished white bowls of Simple Chicken Fried Rice on a gray countertop. ## Easy Chicken Fried Rice. * Add the tamari and toasted sesame oil and cook, stirring to combine, and allow the sauce to soak into the rice, about 2 minutes.", "score": 0.99957615, "raw_content": null}, {"url": "https://www.averiecooks.com/easy-better-takeout-chicken-fried-rice/", "title": "Easy Better-Than-Takeout Chicken Fried Rice - Averie Cooks", "content": "Easiest Fried Rice Recipe with Chicken · It\'s an easy, one-skillet recipe that\'s ready in 20 minutes and better than ...
#               ToolMessage(content='{"query": "one pot chicken and rice recipe", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://iowagirleats.com/one-pot-chicken-and-rice/", "title": "One Pot Chicken and Rice - Family Favorite Recipe - Iowa Girl Eats", "content": "Part risotto (without all the stirring) and part soup, this creamy chicken and rice recipe is simple, comforting, and made entirely in one pot with fridge and pantry staples. 5. **Add a parmesan cheese rind.** This is one of my favorite hacks for adding slow-cooked flavor to quick-cooking soups, especially — drop a parmesan cheese rind into the pot with the chicken stock then let it simmer with the dish. **Step 4:** Season **chicken breasts** that have been chopped into bite-sized pieces with **seasoned salt** and **pepper** then add to the soup pot and continue to simmer until the rice is al dente and the chicken is cooked through, 7-10 additional minutes. Add dried parsley and chicken stock then turn heat up to high to bring to a boil, stirring occasionally to ensure the rice doesn’t stick to the bottom of the pot as it comes to a boil.", "score": 0.9999958, "raw_content": null}, {"url": "https://www.thedinnerbite.com/one-pot-chicken-and-rice/", "title": "One Pot Chicken and Rice - The Dinner Bite", "content": "# One Pot Chicken and Rice. This **one pot chicken and rice** recipe is about to become your family’s favourite. ## **One pot chicken and rice recipe**. Although both chicken and rice recipes on the blog were made in my Instant Pot pressure cooker, I’m listening to my readers who haven’t yet joined the Instant Pot bandwagon and showing you how I make stovetop one-pan chicken and rice in easy steps. Today’s recipe is similar to my Instant Pot chicken and rice and I hope you enjoy it as much as we did. ## **Chicken and Rice Ingredients**. ## **How to make chicken and rice in one pot in easy steps**. rice and chicken in a pan. ### **More rice recipes you will love**. If you made this easy skillet chicken and rice recipe, don’t forget to leave me feedback and rate it 5 stars. ## One Pot Chicken and Rice. ## One Pot Chicken and Rice.", "score": 0.99998844, "raw_content": null}, {"url": "https://www.budgetbytes.com/one-pot-chicken-and-rice/", "title": "One Pot Chicken and Rice - Budget Bytes", "content": "This Chicken and Rice one pot meal is the kind of comfort food I make time and time again, and it’s definitely moving to the top of my list of favorite recipes. This super simple dish includes juicy chicken thighs coated in herbs and spices (not spicy!), sautéed onions, and long grain white rice cooked in vegetable broth. You could also mix in some thawed and chopped frozen broccoli (like I do in my cheesy chicken and rice casserole recipe) when you add the broth! Since I didn’t add any vegetables *in* the pot with my chicken and rice, I added some roasted broccoli on the side. This hearty and delicious chicken and rice combines rich and flavorful rice with well seasoned chicken or an easy one pot meal. ## More One Pot Chicken Recipes. *This Chicken and Rice recipe was originally published 5/21/22. I decided to look up chicken and rice recipes and the photos of this one drew me in.", "score": 0.9999809, "raw_content": null}, {"url": "https://www.youtube.com/watch?v=Vz5SNvpmpno", "title": "I Found the EASIEST One Pot Chicken & Rice Recipe (No Stress!)", "content": "Ingredients 4–5 chicken thighs (bone-in or boneless) 1 cup long grain rice (washed) 2 cups chicken broth 1 small onion, diced 1 bell pepper,", "score": 0.99997854, "raw_content": null}, {"url": "https://www.cookincanuck.com/one-pot-chicken-and-rice/", "title": "One Pot Chicken and Rice - Cookin Canuck", "content": "# One Pot Chicken and Rice. Serve this delicious one pot chicken and rice recipe with a big green salad or a side of steamed vegetables for a healthy dinner the whole family will love.*. One Pot Chicken and Rice is one of those recipes we turn to again a ...
#               ToolMessage(content='{"query": "chicken and rice bake casserole recipe", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.thediaryofarealhousewife.com/chicken-and-rice-casserole/", "title": "Chicken and Rice Casserole - The Diary of a Real Housewife", "content": "* Chicken and Rice Casserole Recipe. **Step Two:** In a large mixing bowl mix cooked chicken, cooked rice, cream of chicken soup, onion powder, garlic powder, salt, pepper, and 1 cup shredded cheddar cheese. To freeze this recipe mix all ingredients together (cooked rice and chicken just like in the recipe) in an alumni casserole dish. * In a large mixing bowl mix cooked chicken, cooked rice, cream of chicken soup, onion powder, garlic powder, salt, pepper, and 1 cup shredded cheddar cheese. To freeze this recipe mix all ingredients together (cooked rice and chicken just like in the recipe) in an alumni casserole dish.", "score": 0.89189607, "raw_content": null}, {"url": "https://tastesbetterfromscratch.com/one-pan-cheesy-chicken-rice/", "title": "One Pan Chicken and Rice Casserole - Tastes Better From Scratch", "content": "Chicken and rice casserole with melted cheese on top, in an oval serving dish. Dinner doesn\'t get easier or more delicious than this cheesy Chicken and Rice casserole, made in just one pan, with a few simple ingredients. It was a compilation of favorite recipes from close friends, and one of the recipes was this cheesy chicken and rice casserole. Cover the dish with aluminum foil (the pan will be very full!) and bake for 1 hour 30 min to 2 hours , or until rice is tender and chicken is cooked through. Chicken and rice casserole with melted cheese on top, in an oval serving dish. My family loves this easy Chicken and Rice casserole, made in just one pan, with a few simple ingredients. Bake:** Cover the dish with aluminum foil (the pan will be very full!) and bake for 1 hour 30 min to 2 hours , or until rice is tender and chicken is cooked through. This was a wonderful recipe for a Chicken and Rice casserole.", "score": 0.8783249, "raw_content": null}, {"url": "https://ohsweetbasil.com/cheesy-cream-cheese-chicken-and-rice-casserole-recipe/", "title": "Cheesy Cream Cheese Chicken and Rice Casserole", "content": "# Cheesy Cream Cheese Chicken and Rice Casserole. * Ingredients for Cheesy Chicken and Rice Casserole. * How to Make Chicken and Rice Casserole. * Video for How to Make Cream Cheese Chicken and Rice Casserole. * Chicken and Rice Casserole Recipe. ## Ingredients for Cheesy Chicken and Rice Casserole. ## How to Make Chicken and Rice Casserole. ## Video for How to Make Cream Cheese Chicken and Rice Casserole. ## Chicken and Rice Casserole. * In a large mixing bowl, combine the cooked chicken, rice, butter and cream cheese mixture, cream of chicken soup, garlic, Italian dressing mix, chicken stock, half of the shredded cheese, and salt and pepper. 3 Cups Cooked Chicken, 3 Cups Cooked Rice, 1 ¼ Cup Cream of Chicken Soup, 3 Cloves Garlic, 0.7 ounce Good Seasons Dry Italian Dressing Mix, 1 Cup Chicken Broth, 2 ½ Cups Colby Jack Cheese, Salt and Pepper. I love that it’s different than other chicken and rice casseroles with the addition of butter, cream cheese, and Italian dressing packet.", "score": 0.8497846, "raw_content": null}, {"url": "https://www.campbells.com/recipes/one-dish-chicken-rice-bake/", "title": "One Dish Chicken & Rice Bake | Campbell\'s® Recipes", "content": "# One Dish Chicken & Rice Bake. ## Newsletter Sign Up. One-Dish Chicken & Rice Bake is a life-changing recipe. Once you know that you can throw uncooked rice and chicken into a baking dish with some condensed cream soup and it bakes up into an amazing one-dish meal, there\'s no going back. This basic recipe is delicious on its own, but you can also easily change it up to make different versions like Buffalo or Mexican (see tips below for how). One-Dish Chicken & Rice Bake- you\'re welcome. While the oven is heating, stir ...
#               ToolMessage(content='{"query": "creamy chicken rice soup recipe", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.budgetbytes.com/creamy-chicken-rice-soup/", "title": "Creamy Chicken and Rice Soup - Budget Bytes", "content": "Soup weather is my favorite kind of weather, mostly because I get to make recipes like this Creamy Chicken and Rice Soup. 2. **If you don’t like creamy soups (this one isn’t *super* creamy),** you can skip the milk mixture at the end of the recipe and use chicken broth instead**.** Then you’ll have yourself a delicious, clear broth chicken and rice soup. 4. **Want to use rotisserie or leftover pulled chicken?** Swap the water for chicken broth, simmer until the rice is cooked, and stir in the shredded chicken to heat through before adding your creamy milk mixture. This Creamy Chicken and Rice Soup recipe is chock full of fresh vegetables, hearty wild rice, and a light but creamy broth. This creamy wild rice and chicken soup is really filling all on its own, but sometimes I like to add a little something on the side. *Our Creamy Chicken and Rice Soup recipe was originally published 10/22/11.", "score": 0.9999902, "raw_content": null}, {"url": "https://www.bowlofdelicious.com/creamy-chicken-rice-soup/", "title": "Creamy Chicken and Rice Soup - Bowl of Delicious", "content": "# Creamy Chicken and Rice Soup. Creamy Chicken and Rice Soup is the ultimate comfort food – creamy, simple, and easy to make with only a few ingredients. This creamy chicken and rice soup recipe is roughly based on my Chicken and Dumplings recipe, which is one of Bowl of Delicious’s most popular recipes. That recipe adds fresh thyme to the dumplings, and this chicken and rice soup uses fresh thyme in the soup itself. ## How to make creamy chicken and rice soup. ## What kinds of rice can I use for chicken rice soup? That said, feel free to use another kind of rice in creamy chicken rice soup! ## How to thicken chicken rice soup. Flour is a common thickener for soups, and it’s what I used in this chicken rice soup recipe. ## Creamy Chicken and Rice Soup. This creamy chicken and rice soup is the ultimate comfort food – simple and flavorful and rich, packed with buttery thyme flavor.", "score": 0.99998164, "raw_content": null}, {"url": "https://themodernproper.com/creamy-chicken-and-rice-soup", "title": "Creamy Chicken and Rice Soup Recipe | The Modern Proper", "content": "## Creamy Chicken And Rice Soup Recipe. Cozy and rich, with a splash of lemon and a dash of dill, this easy-to-love creamy chicken and rice soup recipe is hearty, bright and just right. A pot of creamy chicken and rice soup being stirred, with milk, dill, lemon juice, and tender shredded chicken. A pot of creamy chicken and rice soup, elegantly topped with fresh dill and black pepper for an extra touch of flavor. A pot of creamy chicken and rice soup, elegantly topped with fresh dill and black pepper for an extra touch of flavor. A pot of creamy chicken and rice soup, elegantly topped with fresh dill and black pepper for an extra touch of flavor. Cozy and rich, with a splash of lemon and a dash of dill, this easy-to-love creamy chicken and rice soup recipe is hearty, bright and just right. A pot of creamy chicken and rice soup being stirred, with milk, dill, lemon juice, and tender shredded chicken.", "score": 0.99998033, "raw_content": null}, {"url": "https://cookswithsoul.com/creamy-chicken-and-wild-rice-soup/", "title": "Creamy Chicken and Rice Soup - Cooks with Soul", "content": "# Creamy Chicken and Rice Soup. This **creamy chicken and rice soup** consists of a mirepoix of carrots, celery, and onion simmered in chicken broth and thyme. When I was little, my grandma often made cream of chicken soup, and this creamy chicken and rice soup reminds me of that. ## How to Make Creamy Chicken and Rice Soup. 5. Add the cooked rice and chopped chicken back to the pot. 2. Once you add the cooked diced chicken to the soup ...
#               ToolMessage(content='{"query": "Arroz con pollo recipe leftovers", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "http://mykentuckyhome-kim.blogspot.com/2012/09/quick-and-easy-arroz-con-pollo.html", "title": "Stirring the Pot: Quick and Easy Arroz con Pollo", "content": "I love being creative with the leftover chicken breasts and actually have created a running list of recipes to try with these leftovers. I must confess that most times my leftover chicken turns into some rather tasty chicken quesadillas, mostly because we all love them so. This time around, my leftover chicken inspired me to make a quicker and easier version of this tasty Latin American classic, Arroz con Pollo. Add the sliced or shredded chicken and black beans to the top of the pot (*without stirring the rice*), recover the pot, and cook over very low heat until the chicken and beans are warmed through and the flavors mingle, about 5-6 minutes. Loves me a rotisserie chicken! Most arroz con pollo recipes I\'ve seen have you cook the chicken from scratch which must take forever! I love that this uses pre-cooked chicken. I love my arroz con pollo, but this version sounds delicious,Kim and your pictures are better every time I visit your blog :).", "score": 0.8619225, "raw_content": null}, {"url": "https://www.laylita.com/recipes/latin-style-rice-with-chicken-or-turkey/", "title": "Latin style rice with chicken or turkey {Arroz con pollo o pavo} – Laylita\'s Recipes", "content": "Achiote or annatto | Chicken | Comfort food | Ecuador | Latin America | Leftovers | Main dishes | Poultry | Quick | Rice dishes | South America | Spain | Turkey. ByLayla Pujol  Posted on   Updated on   Achiote or annatto, Chicken, Comfort food, Ecuador, Latin America, Leftovers, Main dishes, Poultry, Quick, Rice dishes, South America, Spain, Turkey. This is my super easy recipe for Latin style rice with chicken or turkey, also known as arroz con pollo o pavo. An easy recipe for Latin style rice with chicken or turkey, also known as arroz con pollo o pavo, to use up roasted chicken or turkey leftovers. * Add the cooked rice, soy sauce, and turkey or chicken broth to taste. Ingredients for Latin style rice with chicken or turkey Cook the diced onions, bell pepper, crushed garlic with oil and spices to make a refrito or sofrito. Ingredients for easy arroz con pollo\xa0Arroz con pollo style rice made with leftover turkey or chicken.", "score": 0.8266142, "raw_content": null}, {"url": "https://ethnicspoon.com/arroz-con-pollo/", "title": "Easy Authentic Arroz con Pollo Recipe – Latin Chicken & Rice - Analida\'s Ethnic Spoon", "content": "# Easy Authentic Arroz con Pollo Recipe – Latin Chicken & Rice. * Add tender seasoned chicken and peas just before the rice finishes cooking to retain freshness and color. * You can also make this dish from leftover rice ***and*** leftover chicken for a super-fast meal. * Step 6: While the rice is cooking, season the chicken breast that has been split in half. * Step 8: In the pan where you cooked the chicken, place the 1 tablespoon olive oil on medium heat, then add the diced carrots, onion, garlic, and recaito. ****Can I use leftover rice to make this?****. Arroz con pollo a traditional rice and chicken dish from Latin American |ethnicspoon.com. ## Easy Authentic Arroz con Pollo Recipe - Latin Chicken & Rice. Authentic arroz con pollo made with recaito, tender chicken, and seasoned rice. Keyword great leftovers, Panama recipes, Puerto rican dishes, Spanish rice and chicken.", "score": 0.82254606, "raw_content": null}, {"url": "https://bitspicy.com/news/arroz-con-pollo", "title": "Arroz con Pollo — Bit Spicy", "content": "Arroz con Pollo is one of many one-pot rice recipes from all over the world: biryani from South Asia, paella from Spain, jambalaya from the Southern US, risotto from Italy… and here we have the Mexican version - translated simply as Rice with Chicken. 4. Add the rice, sweetcorn and the stock/to ...
#               AIMessage(content='Nice! Leftover chicken and rice make a great base for several tasty dishes. Here are some easy ideas you can try, plus what they typically need beyond the chicken and rice.\n\n1) Chicken fried rice\n- What it is: A quick, one-pan main using soy sauce, a bit of oil, and any veggies you have.\n- Why it’s good with leftovers: Fast to assemble, and you can use the chicken and rice you already have.\n- Common add-ins: peas, carrots, onions, eggs, garlic, sesame oil.\n- Example vibe sources: quick weeknight fried rice recipes you’ll find around (pan-fry chicken, add rice, push to the side, scramble an egg or two, toss with soy sauce and veggies).\n\n2) One-pot creamy chicken and rice\n- What it is: A comforting, creamy soup-like skillet dish where the rice cooks in stock with the chicken.\n- Why it’s good with leftovers: Uses plain chicken + rice plus stock and a few aromatics.\n- Common add-ins: onions, garlic, celery, carrots, a little cream or milk, parmesan rind for extra depth (optional).\n\n3) Chicken and rice casserole (bake)\n- What it is: A hearty bake you assemble in a dish and bake until hot and bubbly.\n- Why it’s good with leftovers: Great for make-ahead; freezes well.\n- Common add-ins: cream of chicken/mushroom soup or a creamy sauce, cheese on top, a few frozen or fresh veggies.\n- Tip: If you’ve got a can of soup and cheese, you’re halfway there.\n\n4) Creamy chicken and rice soup\n- What it is: A soothing soup where shredded chicken and cooked rice go into a creamy, well-seasoned broth.\n- Why it’s good with leftovers: Uses the rice as a thickener and bulk.\n- Common add-ins: carrots, celery, onion, herbs (thyme or dill), milk or cream to finish.\n\n5) Arroz con pollo (Latin-style chicken and rice)\n- What it is: A flavorful one-pot rice dish seasoned with garlic, peppers, onions, tomatoes, and spices.\n- Why it’s good with leftovers: Uses shredded or diced chicken; rice stretches it into a complete meal.\n- Common add-ins: bell peppers, peas, olives, capers, tomato sauce, saffron or paprika for color.\n\n6) Quick “leftovers transform” do-this-next idea\n- What it is: Turn chicken-and-rice into wraps, quesadillas, or a simple skillet by tossing with a quick sauce (like a little sour cream or cream cheese with herbs) and maybe some cheese.\n- Why it’s good: Very flexible; uses what you already have.\n\nWould you like me to pull full recipes and step-by-step instructions for any of these? If you pick a couple (for example, “Chicken fried rice” and “Creamy chicken and rice soup”), I’ll fetch detailed recipes and tailor them to your exact ingredients (and offer simple substitutions if you’re missing a item). Also tell me if you have any dietary preferences or extra ingredients on hand (vegetables, cheese, cream, broth, eggs, etc.).', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 2067, 'prompt_tokens': 7196, 'total_tokens': 9263, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1408, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DY1k8mVQVwJc8m81DuFpjCfP6gSUV', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019dbd96-0a2d-7000-960d-0046fcfedaea-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 7196, 'output_tokens': 2067, 'total_tokens': 9263, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 1408}})]}
